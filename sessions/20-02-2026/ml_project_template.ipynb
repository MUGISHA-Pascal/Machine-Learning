# %% [markdown]
# # Machine Learning Project Notebook
# ## Shopping Behavior Dataset

# %% [markdown]
# ## 1. Business Understanding & Problem Definition

# %% [markdown]
# This dataset captures the shopping habits of 3,900 customers. It includes:
# * **Demographics:** Age, Gender, and Location.
# * **Transaction Details:** Item Purchased, Category (Clothing, Footwear, etc.), and Purchase Amount (USD).
# * **Customer Preferences:** Size, Color, Season, and Review Rating.
# * **Loyalty & Behavior:** Subscription Status, Shipping Type, Discount/Promo Code usage, Previous Purchases, and Frequency of Purchases.
# * **Payment Info:** Method used (Credit Card, PayPal, Venmo, etc.).

# %% [markdown]
# ## 2. Target Variable Selection

# %% [markdown]
# **Guiding Questions:**
# * Which feature are we trying to predict?
# * Is this a **Classification** (e.g., predicting 'Yes/No' for Subscription) or **Regression** (e.g., predicting 'Purchase Amount') task?

# %%
import pandas as pd

df = pd.read_csv('shopping_behavior_updated.csv')
df.head()

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# **Guiding question:** Discover which factors (like shipping or discounts) drive higher ratings and revenue.

# %%
df.info()
df.describe(include='all')

# %% [markdown]
# ## 4. Data Cleaning & Quality Check

# %% [markdown]
# **Guiding Questions:**
# * Are there any null values? (Check `df.isnull().sum()`)
# * Are there any outliers in the 'Purchase Amount' that might skew the model?
# * Are the data types correct? (e.g., Is 'Age' an integer?)

# %%
df.isnull().sum()
df.duplicated().sum()

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis (Individual Variables)
# * What is the distribution of the **'Purchase Amount (USD)'**? Is it skewed?
# * What is the most common **'Age'** of our customers?
# * Which **'Category'** (Clothing, Footwear, etc.) has the highest number of purchases?
# * Which **'Color'** and **'Size'** are the most frequently bought?
# * What is the ratio of **'Subscribers'** to **'Non-Subscribers'**?
#
# ### Bivariate Analysis (Relationships)
# * **Gender vs Spend:** Do male or female customers spend more on average?
# * **Location vs Revenue:** Which States are our top 5 revenue generators?
# * **Age vs Rating:** Do younger or older customers leave better reviews?
# * **Seasonality:** Which **'Season'** has the highest total purchase amount?
# * **Subscription vs Frequency:** Do subscribers shop more frequently than non-subscribers?
# * **Shipping vs Rating:** Does 'Express' shipping lead to significantly higher review ratings?
#
# ### Multivariate & Deep Dives
# * Which specific **'Item Purchased'** is the bestseller in the 'Clothing' category?
# * Does the use of a **'Promo Code'** actually lead to a higher total 'Purchase Amount'?
# * How do **'Payment Methods'** vary across different age groups?
# * Is there a specific combination of **'Category' and 'Size'** that is most popular in the 'Winter'?
# * How do **'Previous Purchases'** correlate with the current 'Purchase Amount'?

# %%
import matplotlib.pyplot as plt

df['Subscription Status'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 6. Feature Engineering

# %% [markdown]
# **Guiding Questions:**
# * Can we create a 'Loyalty Score' based on 'Frequency' and 'Previous Purchases'?
# * How should we encode categorical variables like 'Gender' and 'Category'?
# * Should we group 'Locations' into Regions (West, East, etc.)?

# %%
# Example: Create age groups

df['AgeGroup'] = pd.cut(df['Age'], bins=[0,18,35,60,100], labels=['Teen','Young','Adult','Senior'])

# %% [markdown]
# ## 7. Categorical Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 8. Feature Scaling

# %% [markdown]
# ## 7. Data Splitting & 8. Feature Scaling
# **Guiding Questions:**
# * What is our Train/Test split ratio (e.g., 80/20)?
# * Do we need to use `StandardScaler` on 'Age' and 'Purchase Amount'?

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 9. Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Subscription Status', axis=1)
y = df['Subscription Status']

# %% [markdown]
# ## 10. Model Selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## 11. Model Training

# %%
# model = LogisticRegression()
# model.fit(X_train, y_train)

# %% [markdown]
# ## 12. Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## 13. Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## 14. Model Interpretation

# %%
# Feature importance or coefficients

# %% [markdown]
# ## 15. Deployment & Monitoring

# %%
# Save model and notes here
